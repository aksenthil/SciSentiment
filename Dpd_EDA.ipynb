# %%
import numpy as np
import pandas as pd
import os
# import cx_Oracle
os.chdir("E:\Forecast")

# %%
# os.chdir("E:\oracle_python\instantclient\instantclient_18_3")
# connection = cx_Oracle.connect("rptusr", "Rptusr#1608", "10.9.48.13:1555/rptdb")

# %%
# inputs=pd.read_csv('Dpd_customer.csv',sep='\t')
inputs=pd.read_csv('E:/Forecast/dpd_cus_up.csv', sep='\t')
# Out:
# D:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (12,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
inputs.describe()
# Out:
#          PROPOSALID        AMTFIN           AGE      BRANCHID  GROSS_INCOME  \
# count  2.804500e+04  2.804500e+04  27847.000000  28007.000000  8.221000e+03
# mean   5.787382e+07  4.939627e+06     43.666499   1672.522512  1.023289e+05
# std    4.333044e+07  7.124583e+06      9.850640   2462.280546  9.427267e+05
# min    4.738100e+04  7.050000e+04     18.000000      4.000000  0.000000e+00
# 25%    2.384789e+06  1.500000e+06     36.000000     71.000000  0.000000e+00
# 50%    9.082235e+07  2.650000e+06     44.000000    505.000000  1.666667e+04
# 75%    9.168668e+07  5.000000e+06     51.000000    821.000000  4.700000e+04
# max    9.291696e+07  9.210000e+07     88.000000   6553.000000  5.000000e+07
#
#            DEC-14'      JAN-15'      FEB-15'      MAR-15'      APR-15'  \
# count  5487.000000  5733.000000  5967.000000  6229.000000  6455.000000
# mean     25.072171    25.155067    25.085470    24.157168    25.092951
# ...

# %%
# inputs["Customer_type"]='NA'
# inputs["Customer_type"]=np.where((inputs['max_dpd'] == 0), 'Good',inputs['Customer_type'])
# inputs["Customer_type"]=np.where((inputs['max_dpd']  > 0)  & (inputs['max_dpd']  <30), 'Not bad',inputs['Customer_type'])
# inputs["Customer_type"]=np.where((inputs['max_dpd']  > 30) & (inputs['max_dpd'] <90 ), 'bad',inputs['Customer_type'])  
# inputs["Customer_type"]=np.where((inputs['max_dpd'] > 90) , 'Very bad',inputs['Customer_type'])

# %%
#Searching for Missings,type of data and also known the shape of data
print(inputs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28045 entries, 0 to 28044
# Data columns (total 73 columns):
# AGREEMENTNO        28045 non-null object
# PROPOSALID         28045 non-null int64
# AMTFIN             28045 non-null int64
# AGE                27847 non-null float64
# INDV_CORP_FLAG     28045 non-null object
# BRANCHID           28007 non-null float64
# SEX                27847 non-null object
# MARITAL_STATUS     27847 non-null object
# QUALIFICATION      27840 non-null object
# GROSS_INCOME       8221 non-null float64
# COMP_NAME          516 non-null object
# ACCOTYPE           28045 non-null object
# MONTHLY_INCOME     15371 non-null object
# RESIDENCETYPE      3776 non-null object
# CREDIT_FLAG        28005 non-null object
# EMPLOYMENT_TYPE    7834 non-null object
# LMS_BRANCH_ID      28044 non-null object
# BRANCH             28045 non-null object
# DEC-14'            5487 non-null float64
# JAN-15'            5733 non-null float64
# ...

# %%
#Looking unique values
print(inputs.nunique())
# Out:
# AGREEMENTNO        28023
# PROPOSALID         28023
# AMTFIN              5038
# AGE                   65
# INDV_CORP_FLAG         2
# BRANCHID             205
# SEX                    2
# MARITAL_STATUS         3
# QUALIFICATION         10
# GROSS_INCOME        2168
# COMP_NAME            491
# ACCOTYPE              16
# MONTHLY_INCOME      2154
# RESIDENCETYPE         16
# CREDIT_FLAG            2
# EMPLOYMENT_TYPE       13
# LMS_BRANCH_ID        176
# BRANCH               176
# max_dpd              173
# Customer_rank          4
# Customer_type          4
# dtype: int64

# %%
#Looking the data
print(inputs.head())
# Out:
#           AGREEMENTNO  PROPOSALID   AMTFIN   AGE INDV_CORP_FLAG  BRANCHID SEX  \
# 0  X0HEAGD00000767731     1419832  7000000  57.0              I     524.0   M
# 1  X0HEAGD00001048762     1794033  2700000  36.0              I     524.0   M
# 2  X0HEAGD00001059165     1817916  5000000  51.0              I     524.0   M
# 3  X0HEAGD00001060560     1820623  1300000  46.0              I     524.0   F
# 4  X0HEAGD00001067299     1819732  4500000  41.0              I     524.0   M
#
#   MARITAL_STATUS QUALIFICATION  GROSS_INCOME      ...       SEP-18' OCT-18'  \
# 0              M          GRAD      69731.17      ...           0.0     0.0
# 1              M          GRAD      57166.67      ...         574.0   605.0
# 2              M          GRAD           NaN      ...           0.0     0.0
# 3              M          GRAD      14022.50      ...           0.0     0.0
# 4              M          GRAD           NaN      ...           0.0     0.0
#
# ...
